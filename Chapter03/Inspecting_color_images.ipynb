# %%
# !wget https://www.dropbox.com/s/l98lee/Hemanvi.jpeg
# Out:
# --2026-06-05 18:06:28--  https://www.dropbox.com/s/l98lee/Hemanvi.jpeg
# Loaded CA certificate '/etc/ssl/certs/ca-certificates.crt'
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.81.18, 2620:100:6031:18::a27d:5112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.81.18|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘Hemanvi.jpeg’
#
# Hemanvi.jpeg            [ <=>                ]  93.18K  --.-KB/s    in 0.08s
#
# 2026-06-05 18:06:29 (1.10 MB/s) - ‘Hemanvi.jpeg’ saved [95420]

# %%
import cv2, matplotlib.pyplot as plt
# %matplotlib inline

img = cv2.imread('square-crop.jpg')

# %%
img = img[400:650, 240:440, :]
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img)
print(img.shape)
# Out:
# (250, 200, 3)

# %%
crop = img[-3:, -3:]

# %%
print(crop)
plt.imshow(crop)
# Out:
# [[[169 119  94]
#   [169 119  94]
#   [170 120  95]]
#
#  [[169 119  94]
#   [170 120  95]
#   [170 120  95]]
#
#  [[169 119  94]
#   [170 120  95]
#   [170 120  95]]]
